# %%
PATH_TO_LOGS = r'C:\Users\goreh\OneDrive\문서\Out of the Park Developments\OOTP Baseball 24\saved_games\autotest_20230521.lg\news\txt\leagues'

# %%
import os

# %%
for files in os.listdir(PATH_TO_LOGS):
    print (files)
# Out:
# log_1.txt
# log_10.txt
# log_100.txt
# log_1000.txt
# log_1001.txt
# log_1002.txt
# log_1003.txt
# log_1004.txt
# log_1005.txt
# log_1006.txt
# log_1007.txt
# log_1008.txt
# log_1009.txt
# log_101.txt
# log_1010.txt
# log_1011.txt
# log_1012.txt
# log_1013.txt
# log_1014.txt
# log_1015.txt
# log_1016.txt
# log_1017.txt
# log_1018.txt
# log_1019.txt
# log_102.txt
# log_1020.txt
# log_1021.txt
# log_1022.txt
# log_1023.txt
# log_1024.txt
# log_1025.txt
# log_1026.txt
# log_1027.txt
# log_1028.txt
# log_1029.txt
# log_103.txt
# log_1030.txt
# log_1031.txt
# log_1032.txt
# log_1033.txt
# log_1034.txt
# log_1035.txt
# log_1036.txt
# log_1037.txt
# log_1038.txt
# log_1039.txt
# log_104.txt
# log_1040.txt
# log_1041.txt
# log_1042.txt
# log_1043.txt
# log_1044.txt
# log_1045.txt
# log_1046.txt
# log_1047.txt
# log_1048.txt
# log_1049.txt
# log_105.txt
# log_1050.txt
# log_1051.txt
# log_1052.txt
# log_1053.txt
# log_1054.txt
# log_1055.txt
# log_1056.txt
# log_1057.txt
# log_1058.txt
# ...
